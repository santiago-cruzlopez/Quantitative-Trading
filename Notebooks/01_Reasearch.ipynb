# %% [markdown]
# Introduction to the Reasearch Environment
#
# Below is the formula of the mathematical model of a neuron.

# %% [markdown]
# $$OUT = f(W,X) =f(\sum_{i=1}^{n}W_iX_i)$$

# %% [markdown]
# Where:
# *   f = activation function
# *   n = number of elements in the input sequence
# *   W_i = weight of the ith element of the sequence
# *   X_i = ith element of the input sequence

# %%
c = 0
for i in range(315564):
    c += 1
c
# Out:
# 315564

# %%
#The two most common and useful libraries in Quant Finance
import numpy as np
import pandas as pd

#Plotting Library for Pictures/Graphs
import matplotlib.pyplot as plt

# %%
np.mean([164,1,7,55])
# Out:
# np.float64(56.75)

# %%
#Getting Documentation of any library just put ? after it, so you learn how to use it.
np.random.normal(8, 4.5, size=(2, 8))
# Out:
# array([[ 6.89273362,  8.33517747,  3.5363748 ,  6.47363399,  3.49162704,
#          3.25273321,  6.27245551,  5.56932039],
#        [10.55677099, 11.07006877,  5.47619792, 13.77327825,  9.19393877,
#          6.32900826,  9.86636263,  9.3411589 ]])

# %%
#Sample of 100 points with a mean of 0 and standard of 1. This is a standard normal distribution.
X = np.random.normal(0, 1, 50)
print(X)
# Out:
# [-1.06914463 -1.51281806 -0.11565288 -0.23656438  1.0892926   0.16710379
#   0.16183255  0.66619875  1.49280143 -1.392284   -0.60459701 -0.15433991
#  -0.58745645  0.75055144 -1.43631667  0.52072714 -0.02519994 -1.81804489
#   0.005274    0.49584496  0.89037417 -1.55707107  1.68026255  0.7511593
#   1.13948667 -0.15087317  0.20231198  0.49973836  1.75276939  0.63775863
#   0.78892292  0.87210428 -1.21484723  0.21231236  0.15668893  0.86324691
#   0.30733593 -0.31542424  0.20537217 -0.28780155  0.36947381  2.84886067
#   2.58736328 -0.58343022  0.53339348  1.75055366  0.55137704  0.22582408
#   0.56787741  0.92408483]

# %%
plt.plot(X)

# %%
X = np.random.normal(0, 1, 50)
X2 = np.random.normal(0, 1, 50)

plt.plot(X)
plt.plot(X2)
plt.xlabel('Time')
plt.ylabel('Returns')
plt.legend(['X','X2']);

# %%
np.mean(X)
# Out:
# np.float64(-0.2218769432023269)

# %%
np.std(X)
# Out:
# np.float64(0.9220135370336917)

# %%
# pip install yfinance

import yfinance as yf
intc = yf.Ticker("INTC")
data = intc.history(period="1y")

# %%
data
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-06-14 00:00:00-04:00  30.099065  30.367362  30.019568  30.258057
# 2024-06-17 00:00:00-04:00  30.148749  30.804588  29.989757  30.784714
# 2024-06-18 00:00:00-04:00  30.794651  31.271625  30.307740  30.436920
# 2024-06-20 00:00:00-04:00  30.367362  30.913896  30.258056  30.426985
# 2024-06-21 00:00:00-04:00  30.655533  31.162319  30.476668  30.894020
# ...                              ...        ...        ...        ...
# 2025-06-09 00:00:00-04:00  20.219999  20.959999  20.219999  20.480000
# 2025-06-10 00:00:00-04:00  20.500000  22.440001  20.280001  22.080000
# 2025-06-11 00:00:00-04:00  21.780001  21.830000  20.379999  20.680000
# 2025-06-12 00:00:00-04:00  20.500000  20.980000  20.410000  20.770000
# 2025-06-13 00:00:00-04:00  20.330000  20.600000  20.100000  20.139999
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
X = data['Close']
plt.plot(X)
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend(['INTC']);

# %%
np.mean(X)
# Out:
# np.float64(22.884182067871095)

# %%
np.std(X)
# Out:
# np.float64(3.93699531292542)

# %%
intel_dividends = intc.dividends
print(intel_dividends)
# Out:
# Date
# 1992-10-26 00:00:00-05:00    0.003125
# 1993-01-26 00:00:00-05:00    0.003125
# 1993-04-26 00:00:00-04:00    0.003125
# 1993-07-26 00:00:00-04:00    0.003125
# 1993-10-26 00:00:00-04:00    0.003125
#                                ...
# 2023-08-04 00:00:00-04:00    0.125000
# 2023-11-06 00:00:00-05:00    0.125000
# 2024-02-06 00:00:00-05:00    0.125000
# 2024-05-06 00:00:00-04:00    0.125000
# 2024-08-07 00:00:00-04:00    0.125000
# Name: Dividends, Length: 128, dtype: float64

# %%
v = data['Volume']
plt.plot(v)
plt.xlabel('Time')
plt.ylabel('Volume')
plt.legend(['INTC']);

# %%
np.mean(v)
# Out:
# np.float64(83510749.6)

# %%
np.std(v)
# Out:
# np.float64(46893662.10465226)

# %%
#Take the average of the last 60 days at each timepoint
MAVG = pd.Series(X).rolling(60).mean()
plt.plot(X.index, X.values)
plt.plot(MAVG.index, MAVG.values, label='60 Day MA')
plt.ylabel('Close Price')
plt.legend(['INTC','60 Day MA']);

# %%
#Example of three Moving Averages

MAVG1 = pd.Series(X).rolling(10).mean()
MAVG2 = pd.Series(X).rolling(30).mean()
MAVG3 = pd.Series(X).rolling(60).mean()
plt.plot(X.index, X.values)
plt.plot(MAVG1.index, MAVG1.values)
plt.plot(MAVG2.index, MAVG2.values)
plt.plot(MAVG3.index, MAVG3.values)
plt.ylabel('Close Price')
plt.legend(['INTC','10 Day MA','30 Day MA','60 Day MA']);

# %%
# Set the start and end date
start_date = '1990-01-01'
end_date = '2025-06-13'

# Define the ticker list
tickers_list = ['AAPL', 'IBM', 'MSFT', 'WMT']

# Create placeholder for data
data = pd.DataFrame(columns=tickers_list)

# Fetch the data
for ticker in tickers_list:
    data[ticker] = yf.download(ticker,
                               start_date,
                               end_date)['Close']

# Print first 5 rows of the data
data.head()
# Out:
# /tmp/ipykernel_29537/3040891569.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[ticker] = yf.download(ticker,
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_29537/3040891569.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[ticker] = yf.download(ticker,
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_29537/3040891569.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[ticker] = yf.download(ticker,
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_29537/3040891569.py:13: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data[ticker] = yf.download(ticker,
# [*********************100%***********************]  1 of 1 completed
#                 AAPL       IBM      MSFT       WMT
# Date
# ...

# %%
# Plot all the close prices
data.plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
# Recursive implementation of the factorial function.
 
def factorial(n):
    if n == 1: # The base case (termination condition.)
        return 1
    else:
        return n * factorial(n - 1)
 
 
print(factorial(4)) # 4 * 3 * 2 * 1 = 24
# Out:
# 24
