# %% [markdown]
# Z-score is a statistical measure that quantifies the distance between a data point and the mean of a dataset. It's expressed in terms of standard deviations. It indicates how many standard deviations a data point is from the mean of the distribution.
#
# $$ z = \frac{x-\mu}{\sigma} $$

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = yf.download('CIB', start='2020-01-01', end='2025-03-04')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
def z_score(chunk):
    """Calculates the z-score of the last element in the chunk."""
    return (chunk[-1] - chunk.mean()) / chunk.std()

# %%
rolled = data['Close'].rolling(window=20).apply(z_score, raw=True)

# %%
rolled.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
rolled.hist(bins=25)
# Out:
# array([[<Axes: title={'center': 'CIB'}>]], dtype=object)

# %%
min_pct_change = (    
    data
    .Close
    .pct_change()
    .rolling(window=30)
    .min())

# %%
min_pct_change.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
min_pct_change.hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'CIB'}>]], dtype=object)
